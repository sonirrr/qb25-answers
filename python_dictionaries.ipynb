# %% [markdown]
# # Assigment 2 - Python dictionaries and file I/O
#
# ### Overview
# ------------
#
# The GTEx gene expression dataset consists of samples taken from many human subjects across a variety of tissues. From this dataset we have identified a set of highly-expressed tissue-specific genes. In this exercise, you will be pulling the expressing data for those genes but only in their primary tissue of expression and investigating how much variability exists across the sample population.
#
# Biological Learning Objectives
#
# - Use metadata to associate data with subject or sample traits
# - Use descriptive statistics to make inferences about gene expression heterogeneity
#
# Computational Learning Objectives
#
# - Create and modify a dicitionary
# - Use keys to retrieve values stored in a dictionary
# - Step through each key and value in a dictionary inside a `for` loop
# - Open and read a text file
# - Write to a text file
#
# ### Instructions
# ----------------
#
# - Save a copy of this notebook as `~/qbXX-answers/python_dictionaries.ipynb`.
# - Fill in answers in the available code/markdown cells below.
# - Remember to comment your code to help yourself and us know what each part is intended to do.

# %%
# Use this dictionary for identifying genes of interest and their corresponding tissue of interest

gene_tissue = {
    'ENSG00000042832.11': 'Thyroid',
    'ENSG00000091704.9': 'Pancreas',
    'ENSG00000118245.2': 'Testis',
    'ENSG00000122304.10': 'Testis',
    'ENSG00000122852.14': 'Lung',
    'ENSG00000132693.12': 'Liver',
    'ENSG00000134812.7': 'Stomach',
    'ENSG00000135346.8': 'Pituitary',
    'ENSG00000137392.9': 'Pancreas',
    'ENSG00000142515.14': 'Prostate',
    'ENSG00000142615.7': 'Pancreas',
    'ENSG00000142789.19': 'Pancreas',
    'ENSG00000158874.11': 'Liver',
    'ENSG00000162438.11': 'Pancreas',
    'ENSG00000164816.7': 'Small Intestine - Terminal Ileum',
    'ENSG00000164822.4': 'Small Intestine - Terminal Ileum',
    'ENSG00000168925.10': 'Pancreas',
    'ENSG00000168928.12': 'Pancreas',
    'ENSG00000170890.13': 'Pancreas',
    'ENSG00000171195.10': 'Minor Salivary Gland',
    'ENSG00000172179.11': 'Pituitary',
    'ENSG00000175535.6': 'Pancreas',
    'ENSG00000175646.3': 'Testis',
    'ENSG00000182333.14': 'Stomach',
    'ENSG00000187021.14': 'Pancreas',
    'ENSG00000203784.2': 'Testis',
    'ENSG00000204983.13': 'Pancreas',
    'ENSG00000219073.7': 'Pancreas',
    'ENSG00000229859.9': 'Stomach',
    'ENSG00000240338.5': 'Pancreas',
    'ENSG00000254647.6': 'Pancreas',
    'ENSG00000256713.7': 'Stomach',
    'ENSG00000259384.6': 'Pituitary',
    }

# %% [markdown]
# 1. Load sample metadata from "~/Data/GTEx/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt" and create a dictionary of sample metadata associating each sample ID with the tissue it was sampled from
#
#     - This file is tab-separated but some values have spaces in their text so make sure to specify `\t` in the `.split()` method
#     - There are several columns in the metadata file, but you only need to be concerned with `SAMPID` and `SMTSD`, the sample ID and sample tissue, respectively
#     - Your dictionary should use the `SAMPID` as the key and `SMTSD` as the value

# %%
metadata_fname = "/Users/cmdb/Data/GTEx/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt"
metadatafile = open(metadata_fname)
# Create a dictionary to hold the metadata
metadata = {}
line1 = metadatafile.readline()
line1 = line1.strip("\n")
line1 = line1.split("\t")

SAMPID_column = line1.index("SAMPID")
SMTSD_column = line1.index("SMTSD")

# Step through each line of the metadata file
for line in metadatafile:
    line = line.strip("\n")
    data = line.split("\t")
    # Remove the newline character from the line you just read in and split it by the tab character
    #print(data)
    # Add the data to your metadata dictionary, using the "SAMPID" column value as the dictionary key and the "SMTSD" column value as the dictionary value
    metadata[data[SAMPID_column]] = data[SMTSD_column]

print(metadata)
metadatafile.close()
# Out:
# {'GTEX-1117F-0003-SM-58Q7G': 'Whole Blood', 'GTEX-1117F-0003-SM-5DWSB': 'Whole Blood', 'GTEX-1117F-0003-SM-6WBT7': 'Whole Blood', 'GTEX-1117F-0011-R10a-SM-AHZ7F': 'Brain - Frontal Cortex (BA9)', 'GTEX-1117F-0011-R10b-SM-CYKQ8': 'Brain - Frontal Cortex (BA9)', 'GTEX-1117F-0226-SM-5GZZ7': 'Adipose - Subcutaneous', 'GTEX-1117F-0426-SM-5EGHI': 'Muscle - Skeletal', 'GTEX-1117F-0526-SM-5EGHJ': 'Artery - Tibial', 'GTEX-1117F-0626-SM-5N9CS': 'Artery - Coronary', 'GTEX-1117F-0726-SM-5GIEN': 'Heart - Atrial Appendage', 'GTEX-1117F-1326-SM-5EGHH': 'Adipose - Visceral (Omentum)', 'GTEX-1117F-2226-SM-5N9CH': 'Ovary', 'GTEX-1117F-2426-SM-5EGGH': 'Uterus', 'GTEX-1117F-2526-SM-5GZY6': 'Vagina', 'GTEX-1117F-2826-SM-5GZXL': 'Breast - Mammary Tissue', 'GTEX-1117F-2926-SM-5GZYI': 'Skin - Not Sun Exposed (Suprapubic)', 'GTEX-1117F-3026-SM-5GZYU': 'Minor Salivary Gland', 'GTEX-1117F-3226-SM-5N9CT': 'Brain - Cortex', 'GTEX-111CU-0003-SM-58Q95': 'Whole Blood', 'GTEX-111CU-0003-SM-5DWTR': 'Whole Blood', 'GTEX-111CU-0003-SM-6WBUD': 'Whole Blood', 'GTEX-111CU-0126-SM-5GZWZ': 'Adrenal Gland', 'GTEX-111CU-0226-SM-5GZXC': 'Thyroid', 'GTEX-111CU-0326-SM-5GZXO': 'Lung', 'GTEX-111CU-0426-SM-5GZY1': 'Spleen', 'GTEX-111CU-0526-SM-5EGHK': 'Pancreas', 'GTEX-111CU-0626-SM-5EGHL': 'Esophagus - Muscularis', 'GTEX-111CU-0726-SM-5GZYD': 'Esophagus - Mucosa', 'GTEX-111CU-0826-SM-5EGIJ': 'Esophagus - Gastroesophageal Junction', 'GTEX-111CU-0926-SM-5EGIK': 'Stomach', 'GTEX-111CU-1026-SM-5EGIL': 'Adipose - Visceral (Omentum)', 'GTEX-111CU-1126-SM-5EGIM': 'Skin - Not Sun Exposed (Suprapubic)', 'GTEX-111CU-1226-SM-5EGIN': 'Colon - Sigmoid', 'GTEX-111CU-1326-SM-5NQ8L': 'Small Intestine - Terminal Ileum', 'GTEX-111CU-1426-SM-5GZYP': 'Colon - Transverse', 'GTEX-111CU-1526-SM-5N9FS': 'Prostate', 'GTEX-111CU-1726-SM-5EGHM': 'Testis', 'GTEX-111CU-1826-SM-5GZYN': 'Adipose - Subcutaneous', 'GTEX-111CU-1926-SM-5GZYZ': 'Skin - Sun Exposed (Lower leg)', 'GTEX-111CU-2026-SM-5GZZC': 'Muscle - Skeletal', 'GTEX-111CU-2226-SM-5N9G5': 'Nerve - Tibial', 'GTEX-111FC-0001-SM-58Q7U': 'Whole Blood', 'GTEX-111FC-0001-SM-5DWSO': 'Whole Blood', 'GTEX-111FC-0001-SM-6WBTJ': 'Whole Blood', 'GTEX-111FC-0011-R10a-SM-AHZ7K': 'Brain - Frontal Cortex (BA9)', 'GTEX-111FC-0011-R10a-SM-CYKQ9': 'Brain - Frontal Cortex (BA9)', 'GTEX-111FC-0126-SM-5N9DL': 'Skin - Sun Exposed (Lower leg)', 'GTEX-111FC-0226-SM-5N9B8': 'Adipose - Subcutaneous', 'GTEX-111FC-0326-SM-5GZZ1': 'Muscle - Skeletal', 'GTEX-111FC-0426-SM-5N9CV': 'Artery - Tibial', 'GTEX-111FC-0526-SM-5GZZ8': 'Nerve - Tibial', 'GTEX-111FC-0626-SM-5N9CU': 'Heart - Atrial Appendage', 'GTEX-111FC-0826-SM-5GZWO': 'Heart - Left Ventricle', 'GTEX-111FC-0826-SM-CYKRT': 'Heart - Left Ventricle', 'GTEX-111FC-1026-SM-5GZX1': 'Thyroid', 'GTEX-111FC-1126-SM-5GZWU': 'Lung', 'GTEX-111FC-1326-SM-5N9D9': 'Spleen', 'GTEX-111FC-1426-SM-5N9C7': 'Adipose - Subcutaneous', 'GTEX-111FC-1926-SM-5GZYC': 'Testis', 'GTEX-111FC-2026-SM-5GZYO': 'Prostate', 'GTEX-111FC-2526-SM-5GZXU': 'Skin - Not Sun Exposed (Suprapubic)', 'GTEX-111FC-2926-SM-5GZY7': 'Minor Salivary Gland', 'GTEX-111FC-3026-SM-5GZYJ': 'Pituitary', 'GTEX-111FC-3126-SM-5GZZ2': 'Brain - Cortex', 'GTEX-111FC-3326-SM-5GZYV': 'Brain - Cerebellum', 'GTEX-111VG-0004-SM-58Q85': 'Whole Blood', 'GTEX-111VG-0004-SM-5DWSX': 'Whole Blood', 'GTEX-111VG-0004-SM-6WBTS': 'Whole Blood', 'GTEX-111VG-0008-SM-5Q5BG': 'Cells - Cultured fibroblasts', 'GTEX-111VG-0326-SM-5GZX7': 'Heart - Atrial Appendage', 'GTEX-111VG-0526-SM-5N9BW': 'Thyroid', 'GTEX-111VG-0726-SM-5GIDC': 'Lung', 'GTEX-111VG-1626-SM-5EGIO': 'Skin - Not Sun Exposed (Suprapubic)', 'GTEX-111VG-1926-SM-5GIDO': 'Testis', 'GTEX-111VG-2226-SM-5N9DU': 'Colon - Transverse', 'GTEX-111VG-2326-SM-5N9BK': 'Adipose - Subcutaneous', 'GTEX-111VG-2426-SM-5GZXD': 'Skin - Sun Exposed (Lower leg)', 'GTEX-111VG-2526-SM-5GZXP': 'Nerve - Tibial', 'GTEX-111VG-2626-SM-5GZY2': 'Muscle - Skeletal', 'GTEX-111YS-0004-SM-58Q7Y': 'Whole Blood', 'GTEX-111YS-0004-SM-5DWSS': 'Whole Blood', 'GTEX-111YS-0004-SM-6W ...

# %% [markdown]
# 2. Load and process the headeer from the GTEx gene expression file "~/Data/GTEx/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz"
#
#     - You have code that will open the file and read in the header line
#     - Create a list of tissues corresponding to the column names in the header, one tissue per column name (don't worry about which the column is a sample ID or not since column names that aren't sample IDs will just get a "missing" label)
#     - For each value in the header, see if it appears in the dictionary of sample ID/tissues that you created in step 1
#     - If the value is in your dictionary, add the corresponding tissue name (the value in dictionary for that sample ID key) to your tissue list
#     - If the value is not in your dictionary, add "missing" to the tissue list

# %%
# Because this file is a gzip-compressed file, you will be using the `gzip` library that comes with python
import gzip

expression_fname = "/Users/cmdb/Data/GTEx/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz"

# Open the file using the gzip library
fs = gzip.open(expression_fname)

# The file starts with two lines of information before the header, so these are skipped using 2 calls of `.readline()` without keeping the returned data
_ = fs.readline()
_ = fs.readline()

# Gzipped text files are read in as byte strings, not regular strings, so you will see that `.decode()` is included after `.readline()` to convert the input into a string
header = fs.readline().decode().rstrip().split("\t")

# Make sure to close the file when you are done reading it
fs.close()
# Create a list to hold the tissue names
tissues = []

# Step through each value in the header
for value in header:
    #print(metadata.get(value))
    # Check if the value has an entry in the gene_tissue dictionary, adding either the tissue corresponding to that entry or "missing" to your tissues list
    if (metadata.get(value)) is None:
      tissues.append("missing")
    else:
      tissues.append(metadata.get(value))
    
print(tissues)
# Out:
# ['missing', 'missing', 'Adipose - Subcutaneous', 'Muscle - Skeletal', 'Artery - Tibial', 'Artery - Coronary', 'Heart - Atrial Appendage', 'Adipose - Visceral (Omentum)', 'Uterus', 'Vagina', 'Breast - Mammary Tissue', 'Skin - Not Sun Exposed (Suprapubic)', 'Minor Salivary Gland', 'Brain - Cortex', 'Adrenal Gland', 'Thyroid', 'Lung', 'Spleen', 'Pancreas', 'Esophagus - Muscularis', 'Esophagus - Mucosa', 'Esophagus - Gastroesophageal Junction', 'Stomach', 'Adipose - Visceral (Omentum)', 'Skin - Not Sun Exposed (Suprapubic)', 'Colon - Sigmoid', 'Small Intestine - Terminal Ileum', 'Colon - Transverse', 'Prostate', 'Testis', 'Adipose - Subcutaneous', 'Muscle - Skeletal', 'Nerve - Tibial', 'Skin - Sun Exposed (Lower leg)', 'Adipose - Subcutaneous', 'Muscle - Skeletal', 'Artery - Tibial', 'Nerve - Tibial', 'Heart - Atrial Appendage', 'Heart - Left Ventricle', 'Thyroid', 'Lung', 'Spleen', 'Testis', 'Prostate', 'Skin - Not Sun Exposed (Suprapubic)', 'Minor Salivary Gland', 'Brain - Cortex', 'Brain - Cerebellum', 'Cells - Cultured fibroblasts', 'Heart - Atrial Appendage', 'Thyroid', 'Lung', 'Skin - Not Sun Exposed (Suprapubic)', 'Testis', 'Colon - Transverse', 'Adipose - Subcutaneous', 'Skin - Sun Exposed (Lower leg)', 'Nerve - Tibial', 'Muscle - Skeletal', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Adrenal Gland', 'Heart - Atrial Appendage', 'Heart - Left Ventricle', 'Artery - Aorta', 'Lung', 'Thyroid', 'Esophagus - Gastroesophageal Junction', 'Esophagus - Mucosa', 'Esophagus - Muscularis', 'Stomach', 'Pancreas', 'Adipose - Visceral (Omentum)', 'Small Intestine - Terminal Ileum', 'Skin - Not Sun Exposed (Suprapubic)', 'Colon - Transverse', 'Prostate', 'Colon - Sigmoid', 'Breast - Mammary Tissue', 'Testis', 'Nerve - Tibial', 'Artery - Tibial', 'Muscle - Skeletal', 'Adipose - Subcutaneous', 'Cells - EBV-transformed lymphocytes', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Lung', 'Thyroid', 'Adrenal Gland', 'Artery - Coronary', 'Spleen', 'Heart - Atrial Appendage', 'Pancreas', 'Heart - Left Ventricle', 'Adipose - Visceral (Omentum)', 'Skin - Not Sun Exposed (Suprapubic)', 'Artery - Aorta', 'Breast - Mammary Tissue', 'Small Intestine - Terminal Ileum', 'Colon - Sigmoid', 'Colon - Transverse', 'Esophagus - Muscularis', 'Esophagus - Mucosa', 'Esophagus - Gastroesophageal Junction', 'Stomach', 'Adipose - Subcutaneous', 'Skin - Sun Exposed (Lower leg)', 'Artery - Tibial', 'Muscle - Skeletal', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Thyroid', 'Artery - Aorta', 'Lung', 'Pancreas', 'Adipose - Visceral (Omentum)', 'Colon - Transverse', 'Adipose - Subcutaneous', 'Skin - Sun Exposed (Lower leg)', 'Muscle - Skeletal', 'Artery - Tibial', 'Pituitary', 'Brain - Cortex', 'Brain - Cerebellum', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Skin - Sun Exposed (Lower leg)', 'Adipose - Subcutaneous', 'Artery - Tibial', 'Nerve - Tibial', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Thyroid', 'Adipose - Visceral (Omentum)', 'Esophagus - Muscularis', 'Esophagus - Gastroesophageal Junction', 'Vagina', 'Uterus', 'Skin - Sun Exposed (Lower leg)', 'Muscle - Skeletal', 'Pituitary', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Artery - Aorta', 'Thyroid', 'Heart - Atrial Appendage', 'Breast - Mammary Tissue', 'Testis', 'Colon - Sigmoid', 'Muscle - Skeletal', 'Skin - Sun Exposed (Lower leg)', 'Pituitary', 'Brain - Cortex', 'Brain - Cerebellum', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Thyroid', 'Artery - Aorta', 'Heart - Left Ventricle', 'Heart - Atrial Appendage', 'Lung', 'Adipose - Visceral (Omentum)', 'Prostate', 'Testis', 'Colon - Transverse', 'Esophagus - Mucosa', 'Esophagus - Muscularis', 'Stomach', 'Muscle - Skeletal', 'Skin - Sun Exposed (Lower leg)', 'Artery - Tibial', 'Pituitary', 'Adrenal Gland', 'Pancreas', 'Small Intestine - Terminal Ileum', 'Colon - Sigmoid', 'Heart - Atrial Appendage', 'Adipose - Visceral (Omentum)', 'Colon - Transverse', 'Stomach', 'Heart - Left Ventricle', 'Thyroid', 'Lung', 'Breast - Mammary Tissue', 'Pros ...

# %% [markdown]
# 3. Create a list of expression values for each gene in the `gene_tissue` dictionary (given at the start of the exercise), keeping only expression values from the tissue of interest for that gene
#
#     - Since the file is already open, you can keep reading lines from it in, picking up from after the last line read
#     - You will be log-transforming the expression data using the `log2` function from the built-in library `math`
#     - To deal with zeros in expression data, add one before log-transforming expression data

# %%
# Import the log2 function from the math library to transform the expression counts
from math import log2

# Create a dictionary to hold each gene's expression data
gene_expression = {}

# Because this is a large file, for testing purposes you can use only a small portion of the file to test your code
line_counter = 0

# Step through each line of the file
for line in gzip.open(expression_fname):

    ############# REMOVE THIS AND RERUN ONCE YOUR CODE IS WORKING ####################
    # For debugging, use only the first 500 lines of the file.
    #line_counter += 1
    #if line_counter == 500:
       #break
    ############# REMOVE THIS AND RERUN ONCE YOUR CODE IS WORKING ####################
    

    # Convert the line into a string from a byte string, remove the newline character at the end, and split it by tab characters
    fields = line.decode().rstrip().split("\t")

    # Check if this line contains data for a gene we are interested in. If not, skip it
    fields = line.decode().rstrip().split("\t")
    if fields[0] not in gene_tissue:
        continue

    # Determine which tissue we care about for this gene
    tissue = gene_tissue[fields[0]]

    # Create a list in the gene expression dictionary to hold the gene's data
    gene_expression[fields[0]] = []

    # Look at each column position, one by one
    for i in range(len(tissues)):

        # For each column, see if it is from the tissue we care about (using the tissues list). If so, add that field to our gene expression list, first transforming it with log2(1 + float(field[i])) 
        if tissues[i] == tissue:
            gene_expression[fields[0]].append(log2(1 + float(fields[i])))

# %% [markdown]
# 4. For each gene, calculate the mean, standard deviation, and relative standard deviation and write them to a results file
#
#     - You will be using the `mean` and `stdev` functions from the built-in `statistics` library. Both functions accept a list as their input
#     - Format your results for each gene into a string and write that string to your results file
#     - If you want to organize your results better (completely optional!!), you can save your results in a list and sorting them by tissue type before writing them to a file

# %%
# Load the functions to caculcate the mean and standard deviation from a list
from statistics import stdev, mean

# Open a file to write the results to
results = open("Expression Data Analysis.txt", "w")
rel_var = []

# Step through each gene and its expression value list
for line in gene_expression.items(): 
    # Calculate the mean and standard deviation of expression
    mean_exp = mean(line[1])
    # Calculate the relative standard deviation (coefficient of variation, std / #mean)
    rel_std = stdev(line[1])/mean_exp
    #Write the tissue namne, gene name, #mean, standard deviation, and relative standard deviation to your results file
    rel_var.append(gene_tissue.get(line[0]))
    rel_var.append(rel_std)
    results.write(f"{gene_tissue.get(line[0])}, {line[0]}, {mean_exp}, {stdev(line[1])}, {rel_std}")
    #print(f"{gene_tissue.get(line[0])}, {line[0]}, {mean_exp}, {stdev(line[1])}, {rel_std}")
# Close your results file
results.close()
print(rel_var) #this list is to help me complete the next question
# Out:
# ['Pancreas', 0.06503109088255767, 'Pancreas', 0.1177876279731093, 'Pancreas', 0.05074614510181628, 'Pancreas', 0.03564144877440514, 'Testis', 0.11791824286544222, 'Liver', 0.2875552403125156, 'Liver', 0.054821389153249356, 'Testis', 0.11335847046308609, 'Minor Salivary Gland', 0.2568165163261053, 'Pituitary', 0.13183533543166376, 'Pancreas', 0.05552296526199176, 'Pituitary', 0.18301718980763804, 'Pancreas', 0.04640583295252949, 'Pancreas', 0.049139407233868164, 'Small Intestine - Terminal Ileum', 0.30069395169127305, 'Small Intestine - Terminal Ileum', 0.2611958402727668, 'Thyroid', 0.07463416023060992, 'Lung', 0.2873173022007689, 'Stomach', 0.4007168440566386, 'Pancreas', 0.10821010189920609, 'Pancreas', 0.05356319299548535, 'Pancreas', 0.17138691316950458, 'Stomach', 0.5008484862295736, 'Stomach', 0.5262730937685776, 'Stomach', 0.4763541021105254, 'Pancreas', 0.04064669060038226, 'Testis', 0.10195561883308456, 'Testis', 0.10761864220781056, 'Pancreas', 0.04030574392803288, 'Pancreas', 0.02959391720045206, 'Pancreas', 0.06028688906210789, 'Pituitary', 0.13927854797333378, 'Prostate', 0.24494933157655346]

# %% [markdown]
# 5. Looking at your results, answer the following questions
#
#     - Which tissues have low relative variability (rv < 0.2), medium relative variability (0.2 < rv < 0.4), or high relative variability (rv > 0.4)?
#     - Do each of the genes for a given tissue show the same level of relative variability?
#     - Propose an explanation for differences in relative variability you see between tissues based on what you know about their functions.
#     - Were any of the results surpising to you?

# %% [markdown]
# Answers:
# Low relative variability: Pancreas, Testis, Pituitary, Thyroid
# Medium relative variability: Liver, Minor Salivary Gland, Lung, Prostate
# High relative variability: Small intestine - terminal ileum, Stomach
#
# Genes for a given tissue show different numbers of relative variability, but they all fall within the same broad bins (lower than 0.2, between 0.2 and 0.4, and over 0.4).
#
# It is possible that tissues that experience higher cell turnover (like the stomach and the small intestine) show greater relative variability of gene expression because there are many cells in different stages of growth/development at any given time.
# It is also possible that tissues that are involved in a wider array of functions contain many different cell types, which require differences in gene expression to differentiate/carry out their function.
#
# I was surprised that the testis and pituitary and thyroid glands showed such low relative variability. I would have assumed they contained a wider array of cell types in order to carry out their function, but given how specific their functions and their low cell turnover, this makes sense to me.
